# %% [markdown]
# ### 1. Import and data loading

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Load data
df = pd.read_csv("data/chess_games_raw.csv")
df
# Out:
# /tmp/ipykernel_4913/2651139906.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/chess_games_raw.csv")
#                     Event         Site        Date Round                White  \
# 0        Rated Blitz game  lichess.org  2024.01.01     ?             Peixeiro
# 1        Rated Blitz game  lichess.org  2024.01.01     ?            bayad2016
# 2        Rated Blitz game  lichess.org  2024.01.01     ?        FantacticEman
# 3        Rated Blitz game  lichess.org  2024.01.01     ?           Chigorinez
# 4        Rated Blitz game  lichess.org  2024.01.01     ?          syad_bony77
# ...                   ...          ...         ...   ...                  ...
# 3269261  Rated Blitz game            ?  2024.12.31     -            AfricanJo
# 3269262  Rated Blitz game            ?  2024.12.31     -              cad2024
# 3269263  Rated Blitz game            ?  2024.12.31     -  learningchessreally
# 3269264  Rated Blitz game            ?  2024.12.31     -           lotrisking
# 3269265  Rated Blitz game            ?  2024.12.31     -              SHEFFFF
#
#                        Black   Result  ECO  WhiteElo  BlackElo  PlyCount  \
# 0             VaRYemezAmca72      1-0  A14      2504      2371      49.0
# 1                  Yoda-wins  1/2-1/2  E01      2487      2596      71.0
# 2        why_this_bot_exists  1/2-1/2  D35      2915      2921      59.0
# 3                    Luhrman      1-0  B40      2542      2433      71.0
# 4               GERINDRA_BOS      0-1  C48      2473      2658      56.0
# ...                      ...      ...  ...       ...       ...       ...
# 3269261        Yuri_Guenther  1/2-1/2  C47      2665      2655       NaN
# 3269262   emiliofelixramirez      1-0  D23      2537      2449       NaN
# 3269263      BiletskiyDanylo      0-1  A15      2583      2557       NaN
# 3269264               ezis71      1-0  D30      2513      2398       NaN
# 3269265         C0mB1n0v1tch      1-0  C24      2512      2552       NaN
#
#           EventDate EventType   Termination  \
# 0        2024.??.??     blitz  Time forfeit
# 1        2024.??.??     blitz        Normal
# 2        2024.??.??     blitz        Normal
# 3        2024.??.??     blitz        Normal
# 4        2024.??.??     blitz        Normal
# ...             ...       ...           ...
# 3269261         NaN       NaN        Normal
# 3269262         NaN       NaN  Time forfeit
# 3269263         NaN       NaN  Time forfeit
# 3269264         NaN       NaN        Normal
# 3269265         NaN       NaN  Time forfeit
#
#                                                      Moves
# 0        c4 c6 g3 d5 Nf3 Nf6 Bg2 e6 b3 Be7 Bb2 O-O O-O ...
# 1        d4 d5 c4 e6 g3 Nf6 Bg2 Bb4+ Nd2 O-O Nf3 dxc4 O...
# 2        d4 d5 c4 e6 Nc3 Nf6 cxd5 exd5 Bg5 c6 e3 h6 Bh4...
# 3        e4 c5 d4 cxd4 Nf3 e6 Nxd4 Bc5 Nc3 Ne7 Be3 a6 N...
# 4        e4 e5 Nf3 Nf6 Nc3 Nc6 Bb5 Nd4 Nxd4 exd4 Nd5 c6...
# ...                                                    ...
# 3269261  e4 e5 Nf3 Nc6 Nc3 Nf6 d4 exd4 Nxd4 Bb4 Nxc6 bx...
# 3269262  d4 d5 c4 dxc4 Nf3 Nf6 g3 Nc6 Bg2 Be6 O-O h6 Nc...
# 3269263  Nf3 Nf6 c4 e6 Nc3 Be7 e4 O-O d4 c5 d5 exd5 cxd...
# 3269264  d4 d5 c4 e6 Nf3 a6 g3 dxc4 Bg2 b5 O-O Bb7 a4 N...
# 3269265  e4 e5 Nc3 Nf6 Bc4 Nc6 d3 Na5 Bg5 c6 Nf3 Nxc4 d...
#
# [3269266 rows x 15 columns]

# %% [markdown]
# ### 2. Initial data exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3269266 entries, 0 to 3269265
# Data columns (total 15 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Event        object
#  1   Site         object
#  2   Date         object
#  3   Round        object
#  4   White        object
#  5   Black        object
#  6   Result       object
#  7   ECO          object
#  8   WhiteElo     int64
#  9   BlackElo     int64
#  10  PlyCount     float64
#  11  EventDate    object
#  12  EventType    object
#  13  Termination  object
#  14  Moves        object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 374.1+ MB

# %%
df.isnull().sum()
# Out:
# Event                0
# Site                 0
# Date                 0
# Round                0
# White                0
# Black                0
# Result               0
# ECO                336
# WhiteElo             0
# BlackElo             0
# PlyCount       2707355
# EventDate      2707355
# EventType      2711070
# Termination          0
# Moves             1010
# dtype: int64

# %%
df.describe()
# Out:
#            WhiteElo      BlackElo       PlyCount
# count  3.269266e+06  3.269266e+06  561911.000000
# mean   2.569311e+03  2.568953e+03      87.919028
# std    1.342731e+02  1.328460e+02      40.879115
# min    2.300000e+03  2.300000e+03       0.000000
# 25%    2.500000e+03  2.500000e+03      60.000000
# 50%    2.545000e+03  2.545000e+03      81.000000
# 75%    2.620000e+03  2.620000e+03     110.000000
# max    3.367000e+03  3.390000e+03     600.000000

# %%
df["Date"].value_counts()
# Out:
# Date
# 2024.12.28    13967
# 2024.05.11    11704
# 2024.02.10    11302
# 2024.01.22    10984
# 2024.01.13    10935
#               ...
# 2024.06.22     7495
# 2024.08.24     7342
# 2024.08.03     7209
# 2024.10.26     7143
# 2024.09.12     4500
# Name: count, Length: 366, dtype: int64

# %% [markdown]
# ### 3. Drop columns that has many missing data or irrelevant

# %%
df = df.drop(["Site", "Round", "PlyCount", "EventDate", "EventType"], axis=1)
df = df.dropna(subset=["ECO"])
df.isnull().sum()
# Out:
# Event            0
# Date             0
# White            0
# Black            0
# Result           0
# ECO              0
# WhiteElo         0
# BlackElo         0
# Termination      0
# Moves          674
# dtype: int64

# %% [markdown]
# ### 4. Convert data types

# %%
df["WhiteElo"] = df["WhiteElo"].astype(int)
df["BlackElo"] = df["BlackElo"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3268930 entries, 0 to 3269265
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Event        object
#  1   Date         object
#  2   White        object
#  3   Black        object
#  4   Result       object
#  5   ECO          object
#  6   WhiteElo     int64
#  7   BlackElo     int64
#  8   Termination  object
#  9   Moves        object
# dtypes: int64(2), object(8)
# memory usage: 274.3+ MB

# %% [markdown]
# ### 5. Remove * or unfinished games rows

# %%
df = df[df["Result"].isin(["1-0", "0-1", "1/2-1/2"])]
df["Result"].value_counts()
# Out:
# Result
# 1-0        1508107
# 0-1        1338945
# 1/2-1/2     421755
# Name: count, dtype: int64

# %% [markdown]
# ### 6. Drop duplicates

# %%
df[df.duplicated()]
# Out:
#                     Event        Date               White               Black  \
# 8508     Rated Blitz game  2024.01.01          BOT-Feline            Fruity23
# 79331    Rated Rapid game  2024.01.08             Mate-AI           Intron014
# 84624    Rated Rapid game  2024.01.09            caissa-x      FireFishBOT_v2
# 156949   Rated Blitz game  2024.01.17              abcbot         blundar_bot
# 174641   Rated Blitz game  2024.01.18         blundar_bot           FelineBot
# ...                   ...         ...                 ...                 ...
# 2775402  Rated Blitz game  2024.11.09  DTH_Khainguyenlord            ToromBot
# 2775477  Rated Blitz game  2024.11.09  DTH_Khainguyenlord            caissa-x
# 2779408  Rated Blitz game  2024.11.09  DTH_Khainguyenlord          ASliceOfPi
# 2779549  Rated Blitz game  2024.11.09          ASliceOfPi  DTH_Khainguyenlord
# 2788955  Rated Blitz game  2024.11.10  DTH_Khainguyenlord         IntegralBot
#
#           Result  ECO  WhiteElo  BlackElo Termination  \
# 8508     1/2-1/2  A28      2925      2922      Normal
# 79331    1/2-1/2  C67      2930      2945      Normal
# 84624    1/2-1/2  A01      2952      2950      Normal
# 156949   1/2-1/2  B90      2781      2855      Normal
# 174641   1/2-1/2  C89      2860      2947      Normal
# ...          ...  ...       ...       ...         ...
# 2775402      0-1  B06      2867      3049      Normal
# 2775477      0-1  B10      2863      3023      Normal
# 2779408      0-1  B20      2396      2978      Normal
# 2779549      1-0  C10      2978      2394      Normal
# 2788955      0-1  C00      2393      2951      Normal
#
#                                                      Moves
# 8508     c4 e5 Nc3 Nf6 Nf3 Nc6 e4 Bb4 d3 d6 a3 Bc5 b4 B...
# 79331    e4 e5 Nf3 Nc6 Bb5 Nf6 O-O Nxe4 d4 Nd6 Bxc6 dxc...
# 84624    b3 e5 Bb2 Nc6 c4 Nge7 Nf3 d5 cxd5 Nxd5 e4 Ndb4...
# 156949   e4 c5 Nf3 d6 Nc3 Nf6 d4 cxd4 Nxd4 a6 Bc4 e6 Be...
# 174641   e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Nf6 O-O Be7 Re1 b5 Bb...
# ...                                                    ...
# 2775402                                              e4 g6
# 2775477                                              e4 c6
# 2779408                                              e4 c5
# 2779549                                    e4 e6 d4 d5 Nc3
# 2788955                                              e4 e6
#
# [109 rows x 10 columns]

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### 7. Parse and group game type into 3 categories

# %%
# df['Event'].unique()
df["Event"].value_counts()
# Out:
# Event
# Rated Blitz game                                                  2886900
# Rated Rapid game                                                   187101
# Rated Classical game                                                15910
# Rated Blitz tournament https://lichess.org/tournament/winter24       5587
# Rated Blitz tournament https://lichess.org/tournament/spring24       3705
#                                                                    ...
# Rapid swiss https://lichess.org/swiss/x9hxP18d                          1
# Rated Blitz tournament https://lichess.org/tournament/f2S8VZna          1
# Rated Blitz tournament https://lichess.org/tournament/Xz3PCEGv          1
# Rated Rapid tournament https://lichess.org/tournament/7jQZmMYu          1
# Rated Blitz tournament https://lichess.org/tournament/SWFw86u4          1
# Name: count, Length: 8879, dtype: int64

# %%
def extract_time_class(event):
    event_lower = str(event).lower()
    if "blitz" in event_lower:
        return "blitz"
    elif "rapid" in event_lower:
        return "rapid"
    elif "classical" in event_lower:
        return "classical"
    else:
        return np.nan


df["EventType"] = df["Event"].apply(extract_time_class)
df = df[df["EventType"].notna()]
df["EventType"].value_counts(dropna=False)
# Out:
# EventType
# blitz        3061414
# rapid         191327
# classical      15957
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3268698 entries, 0 to 3269265
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Event        object
#  1   Date         object
#  2   White        object
#  3   Black        object
#  4   Result       object
#  5   ECO          object
#  6   WhiteElo     int64
#  7   BlackElo     int64
#  8   Termination  object
#  9   Moves        object
#  10  EventType    object
# dtypes: int64(2), object(9)
# memory usage: 299.3+ MB

# %% [markdown]
# ### 8. Export cleaned data

# %%
df.to_csv("data/chess_games_clean.csv", index=False)
